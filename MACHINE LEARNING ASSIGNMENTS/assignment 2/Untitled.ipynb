# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_boston

# %%
boston = load_boston()

print(type(boston))
# Out:
# <class 'sklearn.utils.Bunch'>

# %%
names = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']

# %%
df = pd.DataFrame(boston.data,columns= names)

# %%
df['Price'] = boston.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
df.he

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.scatter(x=df['RM'], y=df['Price'])

# %%
plt.scatter(x=df['LSTAT'], y=df['Price'])

# %%
plt.figure(figsize=(18, 9))
sns.heatmap(df.corr(), annot = True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.pairplot(data = df,
            x_vars = ['CRIM','ZN','INDUS','CHAS','NOX','RM'],
            y_vars = 'Price')

# %%
sns.pairplot(data = df,
            x_vars = ['AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT'],
            y_vars = 'Price')

# %%
# Train test split

from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, train_size=0.8, \
                                                    random_state=0)

print(df_train.shape)
print(df_test.shape)
# Out:
# (404, 14)
# (102, 14)

# %%
y_train = df_train.pop('Price')
X_train = df_train
X_train.head()
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 220   0.35809   0.0   6.20   1.0  0.507  6.951  88.5  2.8617   8.0  307.0
# 71    0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873   4.0  305.0
# 240   0.11329  30.0   4.93   0.0  0.428  6.897  54.3  6.3361   6.0  300.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012  66.6  5.5605   5.0  311.0
# 417  25.94060   0.0  18.10   0.0  0.679  5.304  89.1  1.6475  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 220     17.4  391.70   9.71
# 71      19.2  376.94   9.88
# 240     16.6  391.25  11.38
# 6       15.2  395.60  12.43
# 417     20.2  127.36  26.64

# %%
from sklearn.linear_model import LinearRegression
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model_1.predict(X_train)
residual = y_train - y_train_pred

sns.displot(residual, kind='kde')

# %%
plt.scatter(y_train, residual)

plt.show()

# %%
y_test = df_test.pop('Price')
X_test = df_test

# %%
y_test_pred = model_1.predict(X_test)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
temp_df
# Out:
#      Actual  Predicted
# 329    22.6  24.889638
# 371    50.0  23.721411
# 219    23.0  29.364999
# 403     8.3  12.122386
# 78     21.2  21.443823
# ..      ...        ...
# 56     24.7  25.442171
# 455    14.1  15.571783
# 60     18.7  17.937195
# 213    28.1  25.305888
# 108    19.8  22.373233
#
# [102 rows x 2 columns]

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# Mean Absolute Error:  3.842909220444499
# Mean Squared Error:  33.44897999767653
# Root Mean Squared Error:  5.783509315085135

# %%
print(metrics.r2_score(y_test, y_test_pred))
# Out:
# 0.5892223849182507

# %%
residual_test = y_test - y_test_pred
sns.boxplot(x=residual_test)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
normalize=pd.DataFrame(scaler.fit_transform(df),
            columns=df.columns, index=df.index) 
print(normalize)
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %% [markdown]
# # implementation of polynomial transformation with change in degree

# %%
X= df[['RM','LSTAT']]
X.head()
# Out:
#       RM  LSTAT
# 0  6.575   4.98
# 1  6.421   9.14
# 2  7.185   4.03
# 3  6.998   2.94
# 4  7.147   5.33

# %%
X.shape
# Out:
# (506, 2)

# %%
y = df['Price']
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Price, dtype: float64

# %%
y.shape
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, \
                                                    y, \
                                                    test_size = 0.20, \
                                                   random_state = 0)

# %%
print(X_train)
# Out:
#         RM  LSTAT
# 220  6.951   9.71
# 71   5.961   9.88
# 240  6.897  11.38
# 6    6.012  12.43
# 417  5.304  26.64
# ..     ...    ...
# 323  5.708  11.74
# 192  7.178   2.87
# 117  6.021  10.30
# 47   6.030  18.80
# 172  5.572  14.69
#
# [404 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit_transform(X_train)
scaler.transform(X_test)
# Out:
# array([[0.53113623, 0.15914894],
#        [0.50871815, 0.2212766 ],
#        [0.53880054, 0.24879433],
#        [0.34259437, 0.51177305],
#        [0.51178387, 0.30099291],
#        [0.43552405, 0.19120567],
#        [0.44912819, 0.27574468],
#        [0.46119946, 0.21446809],
#        [0.27054991, 0.30950355],
#        [0.54493198, 0.25248227],
#        [0.45909178, 0.53588652],
#        [0.59321709, 0.5529078 ],
#        [0.53266909, 0.45560284],
#        [0.20904388, 0.75319149],
#        [0.81260778, 0.00539007],
#        [0.66679441, 0.08539007],
#        [0.51369994, 0.25560284],
#        [0.71392987, 0.06666667],
#        [0.57194865, 0.10212766],
#        [0.43858977, 0.19971631],
#        [0.54895574, 0.1551773 ],
#        [0.444338  , 0.29219858],
#        [0.49166507, 0.3506383 ],
#        [0.55968576, 0.15489362],
#        [0.40639969, 0.24056738],
#        [0.05786549, 0.32907801],
#        [0.46062464, 0.34326241],
#        [0.4115731 , 0.39886525],
# ...

# %%
from sklearn.linear_model import LinearRegression
model_2 = LinearRegression()
model_2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred_new = model_2.predict(X_train)

residual = y_train - y_train_pred_new

sns.distplot(residual)
# Out:
# C:\Users\chint\anaconda3\envs\course\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
y_test_pred_new = model_2.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred_new))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred_new))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred_new)))
# Out:
# Mean Absolute Error:  4.1424446562385615
# Mean Squared Error:  37.38310563877995
# Root Mean Squared Error:  6.114172522817781

# %%
print(metrics.r2_score(y_test, y_test_pred_new))
# Out:
# 0.5409084827186417

# %%
residual_test_2 = y_test - y_test_pred_new
sns.boxplot(x=residual_test_2)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
def deg(degree):
    from sklearn.preprocessing import PolynomialFeatures
    from sklearn import metrics
    
    #polynomial on x_train
    poly_deg = PolynomialFeatures(degree=degree)

    X_train_pd = poly_deg.fit_transform(X_train)

    model_pd = LinearRegression()

    model_pd.fit(X_train_pd, y_train)

    #residual on x_train data
    y_train_pred_pd = model_pd.predict(X_train_pd)

    residual = y_train - y_train_pred_pd

    #polynomial on x_test
    X_test_pd = poly_deg.transform(X_test)

    y_test_pred_pd = model_pd.predict(X_test_pd)

    print('accuracy: ',metrics.r2_score(y_test, y_test_pred_pd))
    
    print('########  Metrics  ########')
    print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred_pd))

    print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred_pd))

    print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred_pd)))
    
    #residual on x_test data
    residual_testpd = y_test - y_test_pred_pd
    sns.boxplot(x=residual_testpd)

# %%
pd.DataFrame(X_train)
# Out:
#         RM  LSTAT
# 220  6.951   9.71
# 71   5.961   9.88
# 240  6.897  11.38
# 6    6.012  12.43
# 417  5.304  26.64
# ..     ...    ...
# 323  5.708  11.74
# 192  7.178   2.87
# 117  6.021  10.30
# 47   6.030  18.80
# 172  5.572  14.69
#
# [404 rows x 2 columns]

# %%
model_pd2=deg
model_pd2(2)
# Out:
# accuracy:  0.654359432805423
# ########  Metrics  ########
# Mean Absolute Error:  3.3415182491807838
# Mean Squared Error:  28.144971863123917
# Root Mean Squared Error:  5.305183490052339

# %%
model_pd3=deg
model_pd3(3)
# Out:
# accuracy:  0.649174578754235
# ########  Metrics  ########
# Mean Absolute Error:  3.2653790122646726
# Mean Squared Error:  28.567166435275915
# Root Mean Squared Error:  5.344826137048418

# %%
model_pd4=deg
model_pd4(4)
# Out:
# accuracy:  0.5824648762214091
# ########  Metrics  ########
# Mean Absolute Error:  3.6403123175897063
# Mean Squared Error:  33.99923338280756
# Root Mean Squared Error:  5.83088615759282

# %%
model_pd5=deg
model_pd5(5)
# Out:
# accuracy:  0.5799820346081329
# ########  Metrics  ########
# Mean Absolute Error:  3.414900832118819
# Mean Squared Error:  34.20140729981457
# Root Mean Squared Error:  5.848196927243008

# %%
model_pd6=deg
model_pd6(6)
# Out:
# accuracy:  0.5711204644913999
# ########  Metrics  ########
# Mean Absolute Error:  3.462559453759505
# Mean Squared Error:  34.92299112205772
# Root Mean Squared Error:  5.909567761017528

# %%
model_pd7=deg
model_pd7(7)
# Out:
# accuracy:  -1.0223059771401526
# ########  Metrics  ########
# Mean Absolute Error:  4.418226768805813
# Mean Squared Error:  164.67321902407159
# Root Mean Squared Error:  12.832506342257213

# %% [markdown]
# # Conclusion: from the results it states that, model_pd2 has better accuracy and low root mean squared error,so we go with model_pd2 for better results.
