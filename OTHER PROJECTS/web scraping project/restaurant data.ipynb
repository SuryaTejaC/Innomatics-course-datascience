'https://www.swiggy.com/restaurants/celeste-baking-kondapur-hyderabad-337186',
'https://www.swiggy.com/restaurants/thindi-kondapur-hyderabad-229994',
'https://www.swiggy.com/restaurants/g-pulla-reddy-sweets-kothaguda-x-road-kondapur-hyderabad-33999',
'https://www.swiggy.com/restaurants/homely-gachibowli-road-kondapur-hyderabad-86073',
'https://www.swiggy.com/restaurants/pind-balluchi-gachibowli-kondapur-hyderabad-286792',
'https://www.swiggy.com/restaurants/the-bowl-company-gachibowli-road-kondapur-hyderabad-86074',
'https://www.swiggy.com/restaurants/la-vista-the-continental-delight-kondapur-hyderabad-295023',
'https://www.swiggy.com/restaurants/sri-srinivasa-hotel-kondapur-hyderabad-356744',
'https://www.swiggy.com/restaurants/kolkata-rolls-gachibowli-miyapur-rd-kondapur-hyderabad-40157',
'https://www.swiggy.com/restaurants/indori-bhiya-beside-jani-masjid-shilpa-park-kondapur-hyderabad-182663',
'https://www.swiggy.com/restaurants/ks-bakers-kondapur-hyderabad-353236',
'https://www.swiggy.com/restaurants/samosa-spot-sri-ramnagar-block-b-kondapur-hyderabad-38194',
'https://www.swiggy.com/restaurants/new-kritunga-restaurant-hanuman-nagar-kondapur-hyderabad-1126',
'https://www.swiggy.com/restaurants/mummy-ki-rasoi-near-rto-office-beside-idea-store-lane-kondapur-hyderabad-1124',
'https://www.swiggy.com/restaurants/eat-italy-kothaguda-kondapur-hyderabad-180335',
'https://www.swiggy.com/restaurants/taste-of-shakes-hafeezpet-kondapur-hyderabad-363170',
'https://www.swiggy.com/restaurants/cake-lamore-kondapur-hyderabad-217545',
'https://www.swiggy.com/restaurants/mohammedia-shawarma-kondapur-hyderabad-345901',
'https://www.swiggy.com/restaurants/immunity-booster-meals-by-lunchbox-hanuman-nagar-kondapur-hyderabad-263564',
'https://www.swiggy.com/restaurants/scoops-kondapur-hyderabad-309926',
'https://www.swiggy.com/restaurants/sri-krishna-food-court-kondapur-hyderabad-359904',
'https://www.swiggy.com/restaurants/desi-bytes-kothaguda-gachibowli-road-kondapur-hyderabad-1382',
'https://www.swiggy.com/restaurants/the-arabian-shawarma-white-field-road-kondapur-hyderabad-136987',
'https://www.swiggy.com/restaurants/thick-shake-house-gachibowli-kondapur-hyderabad-191222',
'https://www.swiggy.com/restaurants/baskin-robbins-sri-ram-nagar-kondapur-hyderabad-344923',
'https://www.swiggy.com/restaurants/steam-picks-momos-kondapur-hyderabad-357727']

# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

import re

# %%
prices=[]
ratings=[]
totalratings=[]
restypes=[]
names=[]
areas=[]
offers=[]

for i in lst:
    url='{}'.format(i)
    
    page = requests.get(url)
    htmlCode = page.text
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all('div', attrs={'class' : '_2Fixt'}):
        
        #price
        price = soup.find('div', attrs={'class' : '_2aZit _2fC4N'})
        a = price.text
        re.findall(r'\d+',a)
        if price is None:
            prices.append(np.NaN)
        else:
            prices.append(price.text)
            
            
        #rating
        rating = soup.find('div', attrs={'class' : '_2aZit _2fC4N'})
        a = rating.text
        re.findall(r'\d\.[0-9]',a)
        if rating is None:
            ratings.append(np.NaN)
        else:
            ratings.append(rating.text)
            
        #total ratings
        
        totalrating = soup.find('span', attrs={'class' : '_1iYuU'})
        if totalrating is None:
            totalratings.append(np.NaN)
        else:
            totalratings.append(totalrating.text)
            
        
        #restaurant type
        
        restype = soup.find('div', attrs={'class' : '_3Plw0 JMACF'})
        if restype is None:
            restypes.append(np.NaN)
        else:
            restypes.append(restype.text)
            
        # name of restaurant
        
        name = soup.find('div', attrs={'class' : 'OEfxz'})
        if name is None:
            names.append(np.NaN)
        else:
            names.append(name.text)
            
        # restaurant area

        area = soup.find('div', attrs={'class' : 'Gf2NS _2Y6HW'})
        a=area.text
        re.findall(r'(Madhapur|Banjara Hills|Kukatpally|Jubilee Hills| Kondapur)',a)
        if area is None:
            areas.append(np.NaN)
        else:
            areas.append(area.text)
            
            
        # offers available for restaurant
        
        offer = soup.find('div', attrs={'class' : 'Z4sK8'})
        a=offer.text
        re.findall(r'^[a-zA-Z]+[0-9]+%',a)
        if offer is None:
            offers.append(np.NaN)
        else:
            offers.append(offer.text)

# %%
print(len(prices))
print(len(ratings))
print(len(totalratings))
print(len(restypes))
print(len(names))
print(len(areas))
print(len(offers))
# Out:
# 480
# 480
# 480
# 480
# 480
# 480
# 480

# %% [markdown]
# # Creating the pandas DataFrame

# %%
df = pd.DataFrame({'names':names,'prices' : prices, 'ratings' : ratings, 'totalratings' : totalratings,
                   'restypes' : restypes,'areas':areas,'offers_in_%':offers})
df

# %% [markdown]
# # Importing the data to a .csv file

# %%
df.to_csv('restaurant_data.csv', index = False)

# %% [markdown]
# # Reading Dataset

# %%
df=pd.read_csv('restaurant_data.csv')
df
# Out:
#                     names                                             prices  \
# 0      Continental Bite's  3.220+ ratings-- MINSDelivery Time₹ 400Cost fo...
# 1           Grameen Kulfi  4.620+ ratings-- MINSDelivery Time₹ 120Cost fo...
# 2                DI PASTA  --Too Few Ratings-- MINSDelivery Time₹ 200Cost...
# 3         Hyderabad Spice  --Too Few RatingsClosedFor Delivery₹ 400Cost f...
# 4         Express By Ab's  3.650+ ratings-- MINSDelivery Time₹ 300Cost fo...
# ..                    ...                                                ...
# 707            Desi Bytes  4.0100+ ratings-- MINSDelivery Time₹ 400Cost f...
# 708  The arabian shawarma  --Too Few RatingsClosedFor Delivery₹ 200Cost f...
# 709     Thick Shake House  4.0100+ ratings-- MINSDelivery Time₹ 300Cost f...
# 710        Baskin Robbins  4.350+ ratings-- MINSDelivery Time₹ 250Cost fo...
# 711     STEAM PICKS MOMOS  --Too Few RatingsClosedFor Delivery₹ 300Cost f...
#
# ...

# %% [markdown]
# # Extracting data using regex

# %%
#prices

regex=r'[0-9]+'
df['prices']=df['prices'].apply(lambda x: re.compile(regex).findall(x))

# %%
#ratings

regex=r'[0-9]\.[0-9]+'
df['ratings']=df['ratings'].apply(lambda x: re.compile(regex).findall(str(x)))

regex='[0-9].[0-9]'
df['ratings']=df['ratings'].apply(lambda x: re.compile(regex).findall(str(x)))

# %%
#totalratings

regex=r'^[0-9]+'
df['totalratings']=df['totalratings'].apply(lambda x: re.compile(regex).findall(x))

# %%
#offers

regex=r'[0-9]+\%'
df['offers']=df['offers'].apply(lambda x: re.compile(regex).findall(str(x)))

# %%
df
# Out:
#                     names          prices     ratings totalratings  \
# 0      Continental Bite's   [3, 220, 400]       [3.2]         [20]
# 1           Grameen Kulfi   [4, 620, 120]       [4.6]         [20]
# 2                DI PASTA           [200]          []           []
# 3         Hyderabad Spice           [400]          []           []
# 4         Express By Ab's   [3, 650, 300]       [3.6]         [50]
# ..                    ...             ...         ...          ...
# 707            Desi Bytes  [4, 0100, 400]  [4.0, 100]        [100]
# 708  The arabian shawarma           [200]          []           []
# 709     Thick Shake House  [4, 0100, 300]  [4.0, 100]        [100]
# 710        Baskin Robbins   [4, 350, 250]       [4.3]         [50]
# 711     STEAM PICKS MOMOS           [300]          []           []
#
#                                               restypes  \
# 0                                  Continental, Snacks
# ...

# %% [markdown]
# # Cleaning Data

# %%
# cleaning data for 'prices' column

l=[]
for i in df['prices']:
    if len(i)>1:
        l.append(i[-1])
    else:
        l.append(i)

# %%
df['cost']=l
df.head()
# Out:
#                 names         prices ratings totalratings  \
# 0  Continental Bite's  [3, 220, 400]   [3.2]         [20]
# 1       Grameen Kulfi  [4, 620, 120]   [4.6]         [20]
# 2            DI PASTA          [200]      []           []
# 3     Hyderabad Spice          [400]      []           []
# 4     Express By Ab's  [3, 650, 300]   [3.6]         [50]
#
#                                             restypes  \
# 0                                Continental, Snacks
# 1                                Ice Cream, Desserts
# 2                                             Pastas
# 3  Opens next at 12 noon, tomorrowBiryani, Chines...
# 4            Barbecue, Biryani, North Indian, Thalis
#
#                                    areas      offers   cost
# 0       Hi-tech City, Madhapur, Madhapur          []    400
# 1                     madhapur, Madhapur  [30%, 50%]    120
# 2                     Madhapur, Madhapur          []  [200]
# ...

# %%
df.drop(['prices'],axis=1,inplace=True)

# %%
# removing '[]' brackets

df['ratings']= df['ratings'].apply(lambda x : ''.join(x))
df['totalratings']= df['totalratings'].apply(lambda x : ''.join(x))
df['cost']= df['cost'].apply(lambda x : ''.join(x))
df['offers']= df['offers'].apply(lambda x : ''.join(x))

# %%
df.head()
# Out:
#                 names ratings totalratings  \
# 0  Continental Bite's     3.2           20
# 1       Grameen Kulfi     4.6           20
# 2            DI PASTA
# 3     Hyderabad Spice
# 4     Express By Ab's     3.6           50
#
#                                             restypes  \
# 0                                Continental, Snacks
# 1                                Ice Cream, Desserts
# 2                                             Pastas
# 3  Opens next at 12 noon, tomorrowBiryani, Chines...
# 4            Barbecue, Biryani, North Indian, Thalis
#
#                                    areas  offers cost
# 0       Hi-tech City, Madhapur, Madhapur          400
# 1                     madhapur, Madhapur  30%50%  120
# 2                     Madhapur, Madhapur          200
# 3  Raheja Mind Space, Sector 3, Madhapur          400
# 4                     Madhapur, Madhapur  20%20%  300

# %%
# cleaning unwanted data from column 'restaurant types'

df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12 noon, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 5 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 7 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 11 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 6 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12 noon, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 3 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 10 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 8 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 7:30 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 11:30 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 9 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12:30 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 1 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 4 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 2 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12:01 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12:15 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 8:30 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 1:15 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 7 am,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 8:30 am,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 11 am,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 9 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 10:30 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 11:10 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 11:59 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12:30 pm,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12:20 pm, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 9:15 am, tomorrow', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 2 pm,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 4 pm,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 6 pm, today', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 12 noon,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Opens next at 5 pm, today', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Wednesday', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace(' Free Delivery ! Limited Stocks!,', ''))
df['restypes'] = df['restypes'].apply(lambda x : x.replace('Restaurant Closed', ''))

# %%
# cleaning unwanted data from column 'ratings'

df['ratings'] = df['ratings'].apply(lambda x : x.replace('100', ''))
df['ratings'] = df['ratings'].apply(lambda x : x.replace('500', ''))

# %%
df.head()
# Out:
#                 names ratings totalratings  \
# 0  Continental Bite's     3.2           20
# 1       Grameen Kulfi     4.6           20
# 2            DI PASTA
# 3     Hyderabad Spice
# 4     Express By Ab's     3.6           50
#
#                                            restypes  \
# 0                               Continental, Snacks
# 1                               Ice Cream, Desserts
# 2                                            Pastas
# 3  Biryani, Chinese, North Indian, Italian, Mexican
# 4           Barbecue, Biryani, North Indian, Thalis
#
#                                    areas  offers cost
# 0       Hi-tech City, Madhapur, Madhapur          400
# 1                     madhapur, Madhapur  30%50%  120
# 2                     Madhapur, Madhapur          200
# 3  Raheja Mind Space, Sector 3, Madhapur          400
# 4                     Madhapur, Madhapur  20%20%  300

# %%
# cleaning unwanted data from 'offers' column

import re
l=[]
for i in df['offers']:
    l.append(re.split('%', i)[0])

# %%
df['offers_in_%']=l

# %%
df.drop(['offers'],axis=1,inplace=True)
df
# Out:
#                     names ratings totalratings  \
# 0      Continental Bite's     3.2           20
# 1           Grameen Kulfi     4.6           20
# 2                DI PASTA
# 3         Hyderabad Spice
# 4         Express By Ab's     3.6           50
# ..                    ...     ...          ...
# 707            Desi Bytes     4.0          100
# 708  The arabian shawarma
# 709     Thick Shake House     4.0          100
# 710        Baskin Robbins     4.3           50
# 711     STEAM PICKS MOMOS
#
#                                              restypes  \
# 0                                 Continental, Snacks
# 1                                 Ice Cream, Desserts
# 2                                              Pastas
# 3    Biryani, Chinese, North Indian, Italian, Mexican
# 4             Barbecue, Biryani, North Indian, Thalis
# ..                                                ...
# 707                     North Indian, Chinese, Bihari
# ...

# %%
# cleaning unwanted data from column 'areas'


regex=r'(Madhapur,|Madhapur)'

df['areas'][0:466]=df['areas'][0:466].apply(lambda x: re.compile(regex).findall(x))


df['areas']= df['areas'].apply(lambda x : ''.join(x))


df['areas'] = df['areas'].apply(lambda x : x.replace('Madhapur,', ''))

# %%
df.head(700)
# Out:
#                        names ratings totalratings  \
# 0         Continental Bite's     3.2           20
# 1              Grameen Kulfi     4.6           20
# 2                   DI PASTA
# 3            Hyderabad Spice
# 4            Express By Ab's     3.6           50
# ..                       ...     ...          ...
# 695             Indori Bhiya     3.4          100
# 696                KS Bakers     4.0          100
# 697              Samosa Spot     4.6           20
# 698  New Kritunga Restaurant     3.8          100
# 699           Mummy Ki Rasoi     4.2          100
#
#                                               restypes  \
# 0                                  Continental, Snacks
# 1                                  Ice Cream, Desserts
# 2                                               Pastas
# 3     Biryani, Chinese, North Indian, Italian, Mexican
# 4              Barbecue, Biryani, North Indian, Thalis
# ..                                                 ...
# ...

# %%
regex=r'(Kondapur,|Kondapur)'

df['areas'][466:493]=df['areas'][466:493].apply(lambda x: re.compile(regex).findall(x))



regex=r'(Kondapur,|Kondapur)'

df['areas'][682:714]=df['areas'][682:714].apply(lambda x: re.compile(regex).findall(x))



df['areas']= df['areas'].apply(lambda x : ''.join(x))


df['areas'] = df['areas'].apply(lambda x : x.replace('Kondapur,', ''))

# %%
df.head(492)
# Out:
#                         names ratings totalratings  \
# 0          Continental Bite's     3.2           20
# 1               Grameen Kulfi     4.6           20
# 2                    DI PASTA
# 3             Hyderabad Spice
# 4             Express By Ab's     3.6           50
# ..                        ...     ...          ...
# 487               SLAY Coffee     4.1          100
# 488   Nanking C.R - Estd 1957
# 489           SRI RAGHAVENDRA
# 490          Marbella's Pizza     3.8           20
# 491  Namkeen By Chaat Company
#
#                                               restypes     areas cost  \
# 0                                  Continental, Snacks  Madhapur  400
# 1                                  Ice Cream, Desserts  Madhapur  120
# 2                                               Pastas  Madhapur  200
# 3     Biryani, Chinese, North Indian, Italian, Mexican  Madhapur  400
# 4              Barbecue, Biryani, North Indian, Thalis  Madhapur  300
# ...

# %%
regex=r'(Jubilee Hills,|Jubilee Hills)'

df['areas'][493:525]=df['areas'][493:525].apply(lambda x: re.compile(regex).findall(x))


regex=r'(Jubliee Hills,|Jubilee Hills)'

df['areas'][650:682]=df['areas'][650:682].apply(lambda x: re.compile(regex).findall(x))


df['areas']= df['areas'].apply(lambda x : ''.join(x))


df['areas'] = df['areas'].apply(lambda x : x.replace('Jubilee Hills,', ''))

# %%
df.head(682)
# Out:
#                               names ratings totalratings  \
# 0                Continental Bite's     3.2           20
# 1                     Grameen Kulfi     4.6           20
# 2                          DI PASTA
# 3                   Hyderabad Spice
# 4                   Express By Ab's     3.6           50
# ..                              ...     ...          ...
# 677                    Almond House     4.5          100
# 678          Sofrehh Persian Bistro     4.3          100
# 679                      Van Lavino     4.2          100
# 680                     SLAY Coffee     4.1          100
# 681  Olio - The Wood Fired Pizzeria     4.0          100
#
#                                              restypes  \
# 0                                 Continental, Snacks
# 1                                 Ice Cream, Desserts
# 2                                              Pastas
# 3    Biryani, Chinese, North Indian, Italian, Mexican
# ...

# %%
regex=r'(Kukatpally,|Kukatpally)'

df['areas'][525:557]=df['areas'][525:557].apply(lambda x: re.compile(regex).findall(x))


regex=r'(Kukatpally,|Kukatpally)'

df['areas'][619:650]=df['areas'][619:650].apply(lambda x: re.compile(regex).findall(x))


df['areas']= df['areas'].apply(lambda x : ''.join(x))


df['areas'] = df['areas'].apply(lambda x : x.replace('Kukatpally,', ''))

# %%
df.head(650)
# Out:
#                         names ratings totalratings  \
# 0          Continental Bite's     3.2           20
# 1               Grameen Kulfi     4.6           20
# 2                    DI PASTA
# 3             Hyderabad Spice
# 4             Express By Ab's     3.6           50
# ..                        ...     ...          ...
# 645          Moghuls Paradiez     4.0          500
# 646          Pange's Panipuri     3.4           50
# 647  SARIGAMA TIFFENS & MEALS
# 648            Zozoz Pizzeria     4.5          100
# 649       ZUCI Chocolates LLP
#
#                                              restypes       areas  cost  \
# 0                                 Continental, Snacks    Madhapur   400
# 1                                 Ice Cream, Desserts    Madhapur   120
# 2                                              Pastas    Madhapur   200
# 3    Biryani, Chinese, North Indian, Italian, Mexican    Madhapur   400
# ...

# %%
regex=r'(Banjara Hills,|Banjara Hills)'

df['areas'][557:619]=df['areas'][557:619].apply(lambda x: re.compile(regex).findall(x))


df['areas']= df['areas'].apply(lambda x : ''.join(x))


df['areas'] = df['areas'].apply(lambda x : x.replace('Banjara Hills,', ''))

# %%
df.head(619)
# Out:
#                       names ratings totalratings  \
# 0        Continental Bite's     3.2           20
# 1             Grameen Kulfi     4.6           20
# 2                  DI PASTA
# 3           Hyderabad Spice
# 4           Express By Ab's     3.6           50
# ..                      ...     ...          ...
# 614           Sanjos Donuts     4.2          100
# 615  Starboy Pizza & Shakes
# 616             All Seasons
# 617            K K S Bakers     4.2          100
# 618                  BELLYS
#
#                                               restypes          areas cost  \
# 0                                  Continental, Snacks       Madhapur  400
# 1                                  Ice Cream, Desserts       Madhapur  120
# 2                                               Pastas       Madhapur  200
# 3     Biryani, Chinese, North Indian, Italian, Mexican       Madhapur  400
# 4              Barbecue, Biryani, North Indian, Thalis       Madhapur  300
# ...

# %%
# removing duplicate values from 'areas'

df['areas'] = df['areas'].apply(lambda x : x.replace('Jubilee Hills areas', 'Jubilee Hills'))
df['areas'] = df['areas'].apply(lambda x : x.replace('KukatpallyKukatpally', 'Kukatpally'))
df['areas'] = df['areas'].apply(lambda x : x.replace('MadhapurMadhapur', 'Madhapur'))
df['areas'] = df['areas'].apply(lambda x : x.replace('Jubilee HillsJubilee Hills', 'Jubilee Hills'))

# %% [markdown]
# # Treating NullValues

# %%
# treating null values for column 'ratings'

l=[]
for i in df['ratings']:
    if len(i)>1:
        l.append(i)
    else:
        l.append('0.0')

# %%
df['Ratings']=l
df.drop(['ratings'],axis=1,inplace=True)
df
# Out:
#                     names totalratings  \
# 0      Continental Bite's           20
# 1           Grameen Kulfi           20
# 2                DI PASTA
# 3         Hyderabad Spice
# 4         Express By Ab's           50
# ..                    ...          ...
# 707            Desi Bytes          100
# 708  The arabian shawarma
# 709     Thick Shake House          100
# 710        Baskin Robbins           50
# 711     STEAM PICKS MOMOS
#
#                                              restypes     areas cost  \
# 0                                 Continental, Snacks  Madhapur  400
# 1                                 Ice Cream, Desserts  Madhapur  120
# 2                                              Pastas  Madhapur  200
# 3    Biryani, Chinese, North Indian, Italian, Mexican  Madhapur  400
# 4             Barbecue, Biryani, North Indian, Thalis  Madhapur  300
# ..                                                ...       ...  ...
# ...

# %%
# treating null values for column 'totalratings'

l=[]
for i in df['totalratings']:
    if len(i)>1:
        l.append(i)
    else:
        l.append('0')

# %%
df['total_rating']=l
df.drop(['totalratings'],axis=1,inplace=True)
df
# Out:
#                     names                                          restypes  \
# 0      Continental Bite's                               Continental, Snacks
# 1           Grameen Kulfi                               Ice Cream, Desserts
# 2                DI PASTA                                            Pastas
# 3         Hyderabad Spice  Biryani, Chinese, North Indian, Italian, Mexican
# 4         Express By Ab's           Barbecue, Biryani, North Indian, Thalis
# ..                    ...                                               ...
# 707            Desi Bytes                     North Indian, Chinese, Bihari
# 708  The arabian shawarma                                Arabian, Fast Food
# 709     Thick Shake House                               Beverages, Desserts
# 710        Baskin Robbins                                          Desserts
# 711     STEAM PICKS MOMOS                                           Chinese
#
#         areas cost offers_in_% Ratings total_rating
# ...

# %%
# treating null values for column 'offers_in_%'

l=[]
for i in df['offers_in_%']:
    if len(i)>1:
        l.append(i)
    else:
        l.append('0')

# %%
df['offers_in_percentage']=l
df.drop(['offers_in_%'],axis=1,inplace=True)
df
# Out:
#                     names                                          restypes  \
# 0      Continental Bite's                               Continental, Snacks
# 1           Grameen Kulfi                               Ice Cream, Desserts
# 2                DI PASTA                                            Pastas
# 3         Hyderabad Spice  Biryani, Chinese, North Indian, Italian, Mexican
# 4         Express By Ab's           Barbecue, Biryani, North Indian, Thalis
# ..                    ...                                               ...
# 707            Desi Bytes                     North Indian, Chinese, Bihari
# 708  The arabian shawarma                                Arabian, Fast Food
# 709     Thick Shake House                               Beverages, Desserts
# 710        Baskin Robbins                                          Desserts
# 711     STEAM PICKS MOMOS                                           Chinese
#
# ...

# %%
# treating null values for column 'areas'


l=[]
for i in df['areas']:
    if len(i)>1:
        l.append(i)
    else:
        l.append('Madhapur')

# %%
df['location']=l
df.drop(['areas'],axis=1,inplace=True)
df
# Out:
#                     names                                          restypes  \
# 0      Continental Bite's                               Continental, Snacks
# 1           Grameen Kulfi                               Ice Cream, Desserts
# 2                DI PASTA                                            Pastas
# 3         Hyderabad Spice  Biryani, Chinese, North Indian, Italian, Mexican
# 4         Express By Ab's           Barbecue, Biryani, North Indian, Thalis
# ..                    ...                                               ...
# 707            Desi Bytes                     North Indian, Chinese, Bihari
# 708  The arabian shawarma                                Arabian, Fast Food
# 709     Thick Shake House                               Beverages, Desserts
# 710        Baskin Robbins                                          Desserts
# 711     STEAM PICKS MOMOS                                           Chinese
#
# ...

# %% [markdown]
# # Typecasting

# %%
df['Ratings']=df['Ratings'].astype('float64')

# %%
df['total_rating']=df['total_rating'].astype('int')

# %%
df['offers_in_percentage']=df['offers_in_percentage'].astype('int')

# %%
df['cost']=df['cost'].astype('int')

# %%
df.dtypes
# Out:
# names                    object
# restypes                 object
# cost                      int32
# Ratings                 float64
# total_rating              int32
# offers_in_percentage      int32
# location                 object
# dtype: object

# %% [markdown]
# # Dataviz

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Questions
#
# - what is lowest and highest cost among all the restaurants?
# - what is lowest and highest ratings among all the restaurants?
# - what is lowest and highest offers among all the restaurants?
# - what are the restaurants names below lowest and highest cost according to areas?
# - what are the restaurant names which provide 0% and 60% offer in all the areas?
# - what are the highest and lowest rated restaurants according to area?

# %% [markdown]
# # Univariate: The analysis of one variable.

# %%
# the highest cost 

df[df['cost'] == df['cost'].max()]
# Out:
#                                names  \
# 83      Gourmet Couch by ITC Kohenur
# 166  Flavours Curated by ITC Kohenur
# 266                 Once Upon a Time
# 557         Flying Spaghetti Monster
#
#                                               restypes  cost  Ratings  \
# 83   Chinese, Pan-Asian, Asian, Korean, Vietnamese,...  1500      4.8
# 166  Indian, Continental, North Indian, Biryani, De...  1500      4.2
# 266                           Hyderabadi, North Indian  1500      0.0
# 557                                    Italian, Pizzas  1500      4.3
#
#      total_rating  offers_in_percentage       location
# 83             20                    20       Madhapur
# 166            20                    20       Madhapur
# 266             0                     0       Madhapur
# 557           100                    10  Banjara Hills

# %%
#the lowest cost

df[df['cost'] == df['cost'].min()]
# Out:
#                               names  \
# 257                 Blends N shakes
# 362  Chatpati Chaat Chai And Juices
# 406                  The Tea Planet
#
#                                               restypes  cost  Ratings  \
# 257  Beverages, Fast Food, Chinese, Indian, Contine...    90      3.3
# 362  Snacks, Chaat, Juices, Beverages, British, Caf...    90      3.6
# 406  Beverages, Snacks, Juices, Home Food, Combo, F...    90      3.7
#
#      total_rating  offers_in_percentage  location
# 257           100                    20  Madhapur
# 362           100                    20  Madhapur
# 406           500                    10  Madhapur

# %%
# highest ratings

df[df['Ratings'] == df['Ratings'].max()]
# Out:
#                      names restypes  cost  Ratings  total_rating  \
# 133             Wow shakes   Indian   340      4.9            20
# 307  MEESALA RAJUGARI MESS   Indian   250      4.9            20
#
#      offers_in_percentage  location
# 133                    50  Madhapur
# 307                    20  Madhapur

# %%
# lowest ratings

df[df['Ratings'] == df['Ratings'].min()]
# Out:
#                                     names  \
# 2                                DI PASTA
# 3                         Hyderabad Spice
# 7                                 wok Box
# 9    Punjabi Tales- By Rayalseema Ruchulu
# 11            Sha Sha - Shandaar Shawarma
# ..                                    ...
# 701                       Taste of Shakes
# 703                   MOHAMMEDIA SHAWARMA
# 706                Sri Krishna Food Court
# 708                  The arabian shawarma
# 711                     STEAM PICKS MOMOS
#
#                                              restypes  cost  Ratings  \
# 2                                              Pastas   200      0.0
# 3    Biryani, Chinese, North Indian, Italian, Mexican   400      0.0
# 7                                             Chinese   250      0.0
# 9             North Indian, Tandoor, Kebabs, Desserts   399      0.0
# 11                                  Lebanese, Arabian   150      0.0
# ...

# %%
# highest total number of ratings

df[df['total_rating'] == df['total_rating'].max()]
# Out:
#                 names                                           restypes  \
# 577  Sarvi Restaurant  Mughlai, Chinese, Hyderabadi, Biryani, North I...
#
#      cost  Ratings  total_rating  offers_in_percentage       location
# 577   250      4.2          5000                    20  Banjara Hills

# %%
# lowest total number of ratings

df[df['total_rating'] == df['total_rating'].min()]
# Out:
#                                     names  \
# 2                                DI PASTA
# 3                         Hyderabad Spice
# 7                                 wok Box
# 9    Punjabi Tales- By Rayalseema Ruchulu
# 11            Sha Sha - Shandaar Shawarma
# ..                                    ...
# 701                       Taste of Shakes
# 703                   MOHAMMEDIA SHAWARMA
# 706                Sri Krishna Food Court
# 708                  The arabian shawarma
# 711                     STEAM PICKS MOMOS
#
#                                              restypes  cost  Ratings  \
# 2                                              Pastas   200      0.0
# 3    Biryani, Chinese, North Indian, Italian, Mexican   400      0.0
# 7                                             Chinese   250      0.0
# 9             North Indian, Tandoor, Kebabs, Desserts   399      0.0
# 11                                  Lebanese, Arabian   150      0.0
# ...

# %%
# highest offer

df[df['offers_in_percentage'] == df['offers_in_percentage'].max()]
# Out:
#                       names                            restypes  cost  \
# 86       THE SHAKE FACTORYS     Beverages, Italian, Continental   200
# 119  The Thickshake Project                Beverages, Ice Cream   200
# 226         Vada Pav & more                   Fast Food, Snacks   200
# 228         Khichdi Express  North Indian, Fast Food, Home Food   250
# 255          Gunpowder Idli                        South Indian   300
# 260           Garam Khichdi                        North Indian   300
# 269            Oh! Calcutta                             Bengali   800
#
#      Ratings  total_rating  offers_in_percentage  location
# 86       0.0             0                    60  Madhapur
# 119      3.1            50                    60  Madhapur
# 226      2.9           100                    60  Madhapur
# 228      3.8           100                    60  Madhapur
# 255      4.1            50                    60  Madhapur
# ...

# %%
# lowest offer

df[df['offers_in_percentage'] == df['offers_in_percentage'].min()]
# Out:
#                                     names  \
# 0                      Continental Bite's
# 2                                DI PASTA
# 3                         Hyderabad Spice
# 9    Punjabi Tales- By Rayalseema Ruchulu
# 11            Sha Sha - Shandaar Shawarma
# ..                                    ...
# 698               New Kritunga Restaurant
# 699                        Mummy Ki Rasoi
# 706                Sri Krishna Food Court
# 708                  The arabian shawarma
# 711                     STEAM PICKS MOMOS
#
#                                              restypes  cost  Ratings  \
# 0                                 Continental, Snacks   400      3.2
# 2                                              Pastas   200      0.0
# 3    Biryani, Chinese, North Indian, Italian, Mexican   400      0.0
# 9             North Indian, Tandoor, Kebabs, Desserts   399      0.0
# 11                                  Lebanese, Arabian   150      0.0
# ...

# %% [markdown]
# # Barplot:It is pictorial representation of data in the form of vertical or horizontal rectangular bars, where the length of bars are proportional to the measure of data.

# %%
# cost
 
plt.figure(figsize=(10,5))
df['cost'].value_counts().head(10).plot.bar()
plt.xlabel('cost')
plt.ylabel('number of restaurants')
# Out:
# Text(0, 0.5, 'number of restaurants')

# %% [markdown]
# # Observation:The lowest cost of restaurants starts from 100 and highest cost starts from 1000.

# %% [markdown]
# # Areaplot:An Area Plot is obtained by filling the region between the Line Chart and the axes with a color.

# %%
# total number of ratings

plt.figure(figsize=(10,5))
df['total_rating'].value_counts().sort_index().plot.area()
plt.xlabel('total number of ratings')
plt.ylabel('number of restaurants')
# Out:
# Text(0, 0.5, 'number of restaurants')

# %% [markdown]
# # Observation:The lowest total number of ratings of restaurant is 0 and highest is 5000 ratings.

# %% [markdown]
# # Lineplot:Displays information as a series of data points connected by straight line segments.

# %%
# lineplot for 'offers in percentage' column


plt.figure(figsize=(10,5))
df['offers_in_percentage'].value_counts().sort_index().plot.line() 
plt.xlabel('offers in percentage')
plt.ylabel('number of restaurants')
# Out:
# Text(0, 0.5, 'number of restaurants')

# %% [markdown]
# # observation:The lowest offer is 0 wheres as highest offer is 60.

# %% [markdown]
# # Piechart:Proportional representation of the numerical data in a column.

# %%
df['total_rating'].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='total_rating'>

# %% [markdown]
# # Observation:From the above pie chart we can understand that more than half of the restaurnats have zero ratings.

# %% [markdown]
# # Bivariate:The analysis of two variables.

# %%
# restaurants names below 200 cost according to areas

df[df['cost'] < 200]
# Out:
#                                              names  \
# 1                                    Grameen Kulfi
# 10                            Murali Krishna Hotel
# 11                     Sha Sha - Shandaar Shawarma
# 13   Kwality Walls Frozen Dessert & Ice Cream Shop
# 19                                     KOKO SHAKES
# ..                                             ...
# 655                                  House of Pops
# 660                                      Roll Call
# 685                                     Khana Wala
# 695                                   Indori Bhiya
# 697                                    Samosa Spot
#
#                                               restypes  cost  Ratings  \
# 1                                  Ice Cream, Desserts   120      4.6
# 10         tomorrowSouth Indian, Biryani, North Indian   100      3.8
# 11                                   Lebanese, Arabian   150      0.0
# ...

# %%
# these are the restaurant names which provide 0% offer in these areas

df[df['offers_in_percentage'] == 0]
# Out:
#                                     names  \
# 0                      Continental Bite's
# 2                                DI PASTA
# 3                         Hyderabad Spice
# 9    Punjabi Tales- By Rayalseema Ruchulu
# 11            Sha Sha - Shandaar Shawarma
# ..                                    ...
# 698               New Kritunga Restaurant
# 699                        Mummy Ki Rasoi
# 706                Sri Krishna Food Court
# 708                  The arabian shawarma
# 711                     STEAM PICKS MOMOS
#
#                                              restypes  cost  Ratings  \
# 0                                 Continental, Snacks   400      3.2
# 2                                              Pastas   200      0.0
# 3    Biryani, Chinese, North Indian, Italian, Mexican   400      0.0
# 9             North Indian, Tandoor, Kebabs, Desserts   399      0.0
# 11                                  Lebanese, Arabian   150      0.0
# ...

# %%
# these are the restaurant names which provide more than 50% offer in these areas

df[df['offers_in_percentage'] > 50]
# Out:
#                       names                            restypes  cost  \
# 86       THE SHAKE FACTORYS     Beverages, Italian, Continental   200
# 119  The Thickshake Project                Beverages, Ice Cream   200
# 226         Vada Pav & more                   Fast Food, Snacks   200
# 228         Khichdi Express  North Indian, Fast Food, Home Food   250
# 255          Gunpowder Idli                        South Indian   300
# 260           Garam Khichdi                        North Indian   300
# 269            Oh! Calcutta                             Bengali   800
#
#      Ratings  total_rating  offers_in_percentage  location
# 86       0.0             0                    60  Madhapur
# 119      3.1            50                    60  Madhapur
# 226      2.9           100                    60  Madhapur
# 228      3.8           100                    60  Madhapur
# 255      4.1            50                    60  Madhapur
# ...

# %%
# restaurants names which has highest ratings accoring to areas

df[df['Ratings'] > 4.7]
# Out:
#                             names  \
# 83   Gourmet Couch by ITC Kohenur
# 133                    Wow shakes
# 287                   FRUITOHOLIC
# 307         MEESALA RAJUGARI MESS
# 336            AMMA TIFFIN CENTER
#
#                                               restypes  cost  Ratings  \
# 83   Chinese, Pan-Asian, Asian, Korean, Vietnamese,...  1500      4.8
# 133                                             Indian   340      4.9
# 287                             Juices, Salads, Snacks   400      4.8
# 307                                             Indian   250      4.9
# 336                                       South Indian   150      4.8
#
#      total_rating  offers_in_percentage  location
# 83             20                    20  Madhapur
# 133            20                    50  Madhapur
# 287            20                     0  Madhapur
# 307            20                    20  Madhapur
# 336            20                     0  Madhapur

# %%
# restaurants names which has lowest ratings accoring to areas

df[df['Ratings'] == 0.0]
# Out:
#                                     names  \
# 2                                DI PASTA
# 3                         Hyderabad Spice
# 7                                 wok Box
# 9    Punjabi Tales- By Rayalseema Ruchulu
# 11            Sha Sha - Shandaar Shawarma
# ..                                    ...
# 701                       Taste of Shakes
# 703                   MOHAMMEDIA SHAWARMA
# 706                Sri Krishna Food Court
# 708                  The arabian shawarma
# 711                     STEAM PICKS MOMOS
#
#                                              restypes  cost  Ratings  \
# 2                                              Pastas   200      0.0
# 3    Biryani, Chinese, North Indian, Italian, Mexican   400      0.0
# 7                                             Chinese   250      0.0
# 9             North Indian, Tandoor, Kebabs, Desserts   399      0.0
# 11                                  Lebanese, Arabian   150      0.0
# ...

# %% [markdown]
# # Scatterplot:Uses dots to represent values for two different variables.

# %%
# highest and lowest cost of restaurants according to areas

plt.figure(figsize=(10,5))
plt.scatter(x=df['location'],y=df['cost'],c='red',marker='D')
plt.xlabel('location')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %% [markdown]
# # Observation:The lowest cost of restaurants are present more in madhapur,kukapally,banjarahills which is below 200 and highest cost restaurants are present in area of madhapur and banjarahills .

# %% [markdown]
# # Violinplot:To visualize the distribution of numerical data of different variables.

# %%
#highest and lowest offers of restaurants according to 'areas'

plt.figure(figsize=(10, 7))
sns.violinplot(x='location',y="offers_in_percentage",data=df)
# Out:
# <AxesSubplot:xlabel='location', ylabel='offers_in_percentage'>

# %% [markdown]
# # Observation:Highest offer restaurants is in madhapur and lowest offer restaurants are present in every area.

# %%
# highest and lowest rated restaurants according to 'area'

plt.figure(figsize=(10,5))
plt.scatter(x=df['location'],y=df['Ratings'],c='red',marker='D')
plt.xlabel('location')
plt.ylabel('Ratings')
# Out:
# Text(0, 0.5, 'Ratings')

# %% [markdown]
# # Observation:Highest rated restaurant is in madhapur(4.9) whereas lowest rated restaurants is also in madhapur along with other areas(0.0).

# %% [markdown]
# # Multivariate:The analysis of two or more variables.

# %% [markdown]
# # Heatmap:Helps in knowing the data intensity,finding the correlation between different sets of attributes.

# %%
plt.figure(dpi = 300)
sns.heatmap(df.corr(),linecolor='white',linewidths=2,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Observation:From the above heatmap we can understand that the highest correaltion between two variables is 0.38 i.e.if ratings increases the total number of ratings also increases.

# %% [markdown]
# # Conclusion:
# - The lowest cost among all restaurants is 100 and highest cost is 1500.
# - The lowest rating among all restaurants is 0.0 and highest rating is 4.9.
# - The lowest offer is 0% while the highest offer is 60%.

# %%
df['restypes']=df['restypes'].astype('category')

# %%
df[['restypes','Ratings']].value_counts().head(20).plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
plt.scatter(x=df['restypes'],y=df['Ratings'],c='red',marker='D')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-fdf68add53d2> in <module>
# ----> 1 plt.scatter(x=df['restypes'],y=df['Ratings'],c='red',marker='D').value_counts().head(10)
#
# AttributeError: 'PathCollection' object has no attribute 'value_counts'
